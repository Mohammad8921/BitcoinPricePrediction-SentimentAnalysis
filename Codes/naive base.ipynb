# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importing the Dataset

# %%
dataset = pd.read_csv('../dataset/dataset_sampled.csv')

# %% [markdown]
# ## Creating Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=1000)
X = cv.fit_transform(dataset['cleaned']).toarray()
y = dataset['Labels']

# %% [markdown]
# ## Creating The Training set and the Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ##  Naïve bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn.metrics import classification_report
nb_pred = nb_model.predict(X_test)
print(classification_report(y_test, nb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.30      0.52      0.38       250
#            1       0.27      0.44      0.33       229
#            2       0.59      0.22      0.33       521
#
#     accuracy                           0.35      1000
#    macro avg       0.39      0.39      0.35      1000
# weighted avg       0.44      0.35      0.34      1000

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(nb_model, X_train, y_train, cv = 10, scoring='accuracy')
print('Mean scores is:',np.mean(scores))
print('Cross-validation scores:{}'.format(scores))
# Out:
# Mean scores is: 0.32811111111111113
# Cross-validation scores:[0.33       0.31111111 0.33777778 0.34222222 0.32666667 0.34666667
#  0.32444444 0.31777778 0.33222222 0.31222222]
